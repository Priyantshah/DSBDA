# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data10.csv')
df.columns = ["col1", "col2", "col3", "col4", "col5"]
df
# Out:
#      col1  col2  col3  col4            col5
# 0     4.9   3.0   1.4   0.2     Iris-setosa
# 1     4.7   3.2   1.3   0.2     Iris-setosa
# 2     4.6   3.1   1.5   0.2     Iris-setosa
# 3     5.0   3.6   1.4   0.2     Iris-setosa
# 4     5.4   3.9   1.7   0.4     Iris-setosa
# ..    ...   ...   ...   ...             ...
# 144   6.7   3.0   5.2   2.3  Iris-virginica
# 145   6.3   2.5   5.0   1.9  Iris-virginica
# 146   6.5   3.0   5.2   2.0  Iris-virginica
# 147   6.2   3.4   5.4   2.3  Iris-virginica
# 148   5.9   3.0   5.1   1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    149 non-null    float64
#  1   col2    149 non-null    float64
#  2   col3    149 non-null    float64
#  3   col4    149 non-null    float64
#  4   col5    149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
columns = len(list(df))
columns
# Out:
# 5

# %%
np.unique(df["col5"])
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.describe()
# Out:
#              col1        col2        col3        col4
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
fig, axes = plt.subplots(2, 2, figsize = (14,10))

axes[0, 0].set_title("Describe the First Column")
axes[0, 0].hist(df["col1"]);

axes[0, 1].set_title("Describe the Second Column")
axes[0, 1].hist(df["col2"]);

axes[1, 0].set_title("Describe the Third Column")
axes[1, 0].hist(df["col3"]);

axes[1, 1].set_title("Describe the Fourth Column")
axes[1, 1].hist(df["col4"]);

# %%
sns.boxplot(x = 'col1', y = 'col2', data = df)
# Out:
# <Axes: xlabel='col1', ylabel='col2'>

# %%
sns.boxplot(x = 'col3', y = 'col4', data = df)
# Out:
# <Axes: xlabel='col3', ylabel='col4'>
